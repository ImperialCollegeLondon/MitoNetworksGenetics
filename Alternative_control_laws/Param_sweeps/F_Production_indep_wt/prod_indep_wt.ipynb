# %% [markdown]
# # Make parameter submission scripts for HPC
#
# ## Control F
#
# Author: Juvid Aryaman

# %%
import numpy as np
import pandas as pd
import mitonetworks.det as mtd
import mitonetworks.stoch as mts

# %%
nominal_params = {
    'beta' : 33.12,
    'gamma' : 0.03785142857142858,
    'xi' : 0.0,
    'alpha' : 5,
    'mu' : 0.023
}

# %%
c_file_param_ordering_convention = ['xi','beta','gamma','alpha','mu']

# %%
hpc_workdir = '/work/ja1109/networks/sing_birth_fus/AJHG_ctrls/F_prod_indep_wt'

# %%
c_filename = 'F_prod_indep_wt'

# %%
hpc_jobname = 'F_piw'

# %%
dc = mts.SubmitHPCSoluableFeedbackControl(ss_definition=mtd.F_production_indep_wt_ss,
                                 nominal_params=nominal_params,hpc_workdir=hpc_workdir,
                                c_filename=c_filename, c_file_param_ordering_convention=c_file_param_ordering_convention,
                                hpc_jobname=hpc_jobname)

# %%
dc.make_submission_scripts()
# Out:
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=0, j=0, h=0.624713979491
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=0, j=1, h=0.565908913825
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=0, j=2, h=0.565804455515
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=0, j=3, h=0.506829385818
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=0, j=4, h=0.562347570635
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=0, j=5, h=0.223698049419
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=0, j=6, h=0.383724245347
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=0, j=7, h=0.430527253269
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=0, j=8, h=0.446730042119
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=0, j=9, h=0.453792092266
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=0, j=10, h=0.456100249912
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=1, j=0, h=0.424102855661
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=1, j=1, h=0.384332396254
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=1, j=2, h=0.389200506601
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=1, j=3, h=0.346316424048
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=1, j=4, h=0.387840148965
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=1, j=5, h=0.195293034457
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=1, j=6, h=0.272132576151
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=1, j=8, h=0.309294139811
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=1, j=9, h=0.313088493687
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=1, j=10, h=0.314385507474
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=2, j=0, h=0.327146508881
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=2, j=1, h=0.322001012941
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=2, j=2, h=0.33031426244
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=2, j=3, h=0.314478941824
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=2, j=4, h=0.333221039783
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=2, j=5, h=0.258413719128
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=2, j=6, h=0.286131075094
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=2, j=7, h=0.296984530037
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=2, j=10, h=0.30307549461
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=3, j=0, h=0.283237273837
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=3, j=2, h=0.308400094812
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=3, j=3, h=0.304579408956
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=3, j=4, h=0.313913630165
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=3, j=5, h=0.28666327573
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=3, j=6, h=0.296903712027
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=4, j=0, h=0.303177447675
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=4, j=1, h=0.291646500278
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=4, j=3, h=0.303207088072
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=4, j=4, h=0.307598706689
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=4, j=7, h=0.303392829053
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=4, j=8, h=0.303302508911
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=4, j=9, h=0.30359837286
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:215: UserWarning: Heteroplasmy target not reached, i=4, j=10, h=0.30371615842
#   warn("Heteroplasmy target not reached, i={0}, j={1}, h={2}".format(i,j,h_param), UserWarning)
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=7, j=0
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=7, j=1
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=7, j=2
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=7, j=3
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=7, j=4
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=7, j=5
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=7, j=6
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=7, j=7
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=7, j=8
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=7, j=9
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=7, j=10
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=8, j=0
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=8, j=1
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=8, j=2
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=8, j=3
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=8, j=4
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=8, j=5
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=8, j=6
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=8, j=7
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=8, j=8
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=8, j=9
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=8, j=10
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=9, j=0
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=9, j=1
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=9, j=2
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=9, j=3
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=9, j=4
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=9, j=5
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=9, j=6
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=9, j=7
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=9, j=8
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=9, j=9
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=9, j=10
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=10, j=0
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=10, j=1
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=10, j=2
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=10, j=3
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=10, j=4
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=10, j=5
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=10, j=6
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=10, j=7
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=10, j=8
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=10, j=9
#   warn("SS not found, i={0}, j={1}".format(i,j))
# /home/juvid/anaconda2/lib/python2.7/site-packages/mitonetworks/stoch.py:226: UserWarning: SS not found, i=10, j=10
#   warn("SS not found, i={0}, j={1}".format(i,j))

# %%
dc.param_df
# Out:
#      alpha         beta       gamma         h         mag  mf_init  ms_init  \
# 0        5     0.331200    0.000004  0.624714    0.010000     50.0    362.0
# 1        5     0.831937    0.000010  0.565909    0.025119     17.0    284.0
# 2        5     2.089731    0.000024  0.565804    0.063096      8.0    284.0
# 3        5     5.249166    0.000060  0.506829    0.158489      3.0    222.0
# 4        5    13.185309    0.000151  0.562348    0.398107      3.0    279.0
# 5        5    33.120000    0.000379  0.223698    1.000000      0.0     63.0
# 6        5    83.193679    0.000951  0.383724    2.511886      1.0    135.0
# 7        5   208.973072    0.002388  0.430527    6.309573      1.0    164.0
# 8        5   524.916625    0.005999  0.446730   15.848932      1.0    176.0
# 9        5  1318.530949    0.015069  0.453792   39.810717      1.0    180.0
# 10       5  3312.000000    0.037851  0.456100  100.000000      1.0    182.0
# 11       5     0.331200    0.000010  0.424103    0.010000     23.0    160.0
# 12       5     0.831937    0.000024  0.384332    0.025119      9.0    135.0
# 13       5     2.089731    0.000060  0.389201    0.063096      4.0    138.0
# 14       5     5.249166    0.000151  0.346316    0.158489      2.0    115.0
# 15       5    13.185309    0.000379  0.387840    0.398107      2.0    138.0
# 16       5    33.120000    0.000951  0.195293    1.000000      0.0     52.0
# 17       5    83.193679    0.002388  0.272133    2.511886      1.0     81.0
# 18       5   208.973072    0.005999  0.298569    6.309573      1.0     93.0
# 19       5   524.916625    0.015069  0.309294   15.848932      1.0     97.0
# 20       5  1318.530949    0.037851  0.313088   39.810717      1.0     99.0
# 21       5  3312.000000    0.095078  0.314386  100.000000      1.0    100.0
# 22       5     0.331200    0.000024  0.327147    0.010000     16.0    105.0
# 23       5     0.831937    0.000060  0.322001    0.025119      8.0    103.0
# 24       5     2.089731    0.000151  0.330314    0.063096      5.0    107.0
# 25       5     5.249166    0.000379  0.314479    0.158489      3.0     99.0
# 26       5    13.185309    0.000951  0.333221    0.398107      3.0    109.0
# 27       5    33.120000    0.002388  0.258414    1.000000      2.0     76.0
# 28       5    83.193679    0.005999  0.286131    2.511886      2.0     87.0
# 29       5   208.973072    0.015069  0.296985    6.309573      2.0     91.0
# ..     ...          ...         ...       ...         ...      ...      ...
# 91       5     5.249166    0.095078       NaN    0.158489      NaN      NaN
# 92       5    13.185309    0.238826       NaN    0.398107      NaN      NaN
# 93       5    33.120000    0.599905       NaN    1.000000      NaN      NaN
# 94       5    83.193679    1.506893       NaN    2.511886      NaN      NaN
# 95       5   208.973072    3.785143       NaN    6.309573      NaN      NaN
# 96       5   524.916625    9.507849       NaN   15.848932      NaN      NaN
# 97       5  1318.530949   23.882637       NaN   39.810717      NaN      NaN
# 98       5  3312.000000   59.990471       NaN  100.000000      NaN      NaN
# 99       5     0.331200    0.015069       NaN    0.010000      NaN      NaN
# 100      5     0.831937    0.037851       NaN    0.025119      NaN      NaN
# 101      5     2.089731    0.095078       NaN    0.063096      NaN      NaN
# 102      5     5.249166    0.238826       NaN    0.158489      NaN      NaN
# 103      5    13.185309    0.599905       NaN    0.398107      NaN      NaN
# 104      5    33.120000    1.506893       NaN    1.000000      NaN      NaN
# 105      5    83.193679    3.785143       NaN    2.511886      NaN      NaN
# 106      5   208.973072    9.507849       NaN    6.309573      NaN      NaN
# 107      5   524.916625   23.882637       NaN   15.848932      NaN      NaN
# 108      5  1318.530949   59.990471       NaN   39.810717      NaN      NaN
# 109      5  3312.000000  150.689251       NaN  100.000000      NaN      NaN
# 110      5     0.331200    0.037851       NaN    0.010000      NaN      NaN
# 111      5     0.831937    0.095078       NaN    0.025119      NaN      NaN
# 112      5     2.089731    0.238826       NaN    0.063096      NaN      NaN
# 113      5     5.249166    0.599905       NaN    0.158489      NaN      NaN
# 114      5    13.185309    1.506893       NaN    0.398107      NaN      NaN
# 115      5    33.120000    3.785143       NaN    1.000000      NaN      NaN
# 116      5    83.193679    9.507849       NaN    2.511886      NaN      NaN
# 117      5   208.973072   23.882637       NaN    6.309573      NaN      NaN
# 118      5   524.916625   59.990471       NaN   15.848932      NaN      NaN
# 119      5  1318.530949  150.689251       NaN   39.810717      NaN      NaN
# 120      5  3312.000000  378.514286       NaN  100.000000      NaN      NaN
#
#         mu         rat  wf_init  ws_init   xi
# 0    0.023    0.010000     30.0    217.0  0.0
# 1    0.023    0.010000     13.0    217.0  0.0
# 2    0.023    0.010000      6.0    217.0  0.0
# 3    0.023    0.010000      3.0    217.0  0.0
# 4    0.023    0.010000      2.0    217.0  0.0
# 5    0.023    0.010000      1.0    217.0  0.0
# 6    0.023    0.010000      1.0    217.0  0.0
# 7    0.023    0.010000      1.0    217.0  0.0
# 8    0.023    0.010000      1.0    217.0  0.0
# 9    0.023    0.010000      1.0    217.0  0.0
# 10   0.023    0.010000      1.0    217.0  0.0
# 11   0.023    0.025119     31.0    217.0  0.0
# 12   0.023    0.025119     14.0    217.0  0.0
# 13   0.023    0.025119      7.0    217.0  0.0
# 14   0.023    0.025119      4.0    217.0  0.0
# 15   0.023    0.025119      3.0    217.0  0.0
# 16   0.023    0.025119      2.0    217.0  0.0
# 17   0.023    0.025119      2.0    217.0  0.0
# 18   0.023    0.025119      2.0    217.0  0.0
# 19   0.023    0.025119      2.0    217.0  0.0
# 20   0.023    0.025119      2.0    217.0  0.0
# 21   0.023    0.025119      2.0    217.0  0.0
# 22   0.023    0.063096     34.0    217.0  0.0
# 23   0.023    0.063096     17.0    217.0  0.0
# 24   0.023    0.063096     10.0    217.0  0.0
# 25   0.023    0.063096      7.0    217.0  0.0
# 26   0.023    0.063096      6.0    217.0  0.0
# 27   0.023    0.063096      5.0    217.0  0.0
# 28   0.023    0.063096      5.0    217.0  0.0
# 29   0.023    0.063096      5.0    217.0  0.0
# ..     ...         ...      ...      ...  ...
# 91   0.023   15.848932      NaN      NaN  0.0
# 92   0.023   15.848932      NaN      NaN  0.0
# 93   0.023   15.848932      NaN      NaN  0.0
# 94   0.023   15.848932      NaN      NaN  0.0
# 95   0.023   15.848932      NaN      NaN  0.0
# 96   0.023   15.848932      NaN      NaN  0.0
# 97   0.023   15.848932      NaN      NaN  0.0
# 98   0.023   15.848932      NaN      NaN  0.0
# 99   0.023   39.810717      NaN      NaN  0.0
# 100  0.023   39.810717      NaN      NaN  0.0
# 101  0.023   39.810717      NaN      NaN  0.0
# 102  0.023   39.810717      NaN      NaN  0.0
# 103  0.023   39.810717      NaN      NaN  0.0
# 104  0.023   39.810717      NaN      NaN  0.0
# 105  0.023   39.810717      NaN      NaN  0.0
# 106  0.023   39.810717      NaN      NaN  0.0
# 107  0.023   39.810717      NaN      NaN  0.0
# 108  0.023   39.810717      NaN      NaN  0.0
# 109  0.023   39.810717      NaN      NaN  0.0
# 110  0.023  100.000000      NaN      NaN  0.0
# 111  0.023  100.000000      NaN      NaN  0.0
# 112  0.023  100.000000      NaN      NaN  0.0
# 113  0.023  100.000000      NaN      NaN  0.0
# 114  0.023  100.000000      NaN      NaN  0.0
# 115  0.023  100.000000      NaN      NaN  0.0
# 116  0.023  100.000000      NaN      NaN  0.0
# 117  0.023  100.000000      NaN      NaN  0.0
# 118  0.023  100.000000      NaN      NaN  0.0
# 119  0.023  100.000000      NaN      NaN  0.0
# 120  0.023  100.000000      NaN      NaN  0.0
#
# [121 rows x 12 columns]

# %% [markdown]
# Largest copy number

# %%
dc.param_df[['mf_init', 'ms_init', 'wf_init', 'ws_init']].sum(axis=1).max()
# Out:
# 3081.0

# %% [markdown]
# Job number of the job anticipated to take the longest time

# %%
jmax = np.argmax(dc.param_df[['mf_init', 'ms_init', 'wf_init', 'ws_init']].sum(axis=1))
jmax
# Out:
# 66

# %% [markdown]
# Corresponding parametrization

# %%
dc.param_df.iloc[jmax]
# Out:
# alpha         5.000000
# beta          0.331200
# gamma         0.000951
# h             0.300098
# mag           0.010000
# mf_init     831.000000
# ms_init      93.000000
# mu            0.023000
# rat           2.511886
# wf_init    1940.000000
# ws_init     217.000000
# xi            0.000000
# Name: 66, dtype: float64

# %% [markdown]
# Number of failed parametrizations

# %%
dc.param_df.isnull().any(axis=1).sum()
# Out:
# 44

# %%
np.all(dc.nominal_params['gamma']*dc.param_df['mag']*dc.param_df['rat'] == dc.param_df['gamma'])
# Out:
# True
